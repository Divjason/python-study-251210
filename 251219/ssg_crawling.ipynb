# %%
# yes24 > requests 라이브러리 모듈 접근 > 크롤링 가능!!!
# 비교적 최근 업데이트 및 리뉴얼, 사이트 제작 >requests 크롤링 절대 안됨!!

# Meta / facebook => 마크주커버그 => React.js // 사이트 // JS
# html, css, js => 단점 A 사이트 정보 => 1000개 (이미지, 텍스트, 코드, 영상 등) => 1개 하트 모양 => 색상
# SNS => 페이스북, 인스타그램 10억명 이상 => 가수 // 천문학적인 서버 유지 비용!!

# 1개의 사이트 => 조립부품 쪼개서 => 1000개 => 1개 부품 => 999개 => components // SPA
# SPA 생성 => JS

# selenium 라이브러리 모듈
# 가상 브라우저 생성
# 브라우저가 되기 위한 필수 조건
# 브라우저 드라이버 설치

# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install webdriver_manager
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

service = Service(ChromeDriverManager().install())

options = Options()
# options.add_argument("--headless")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920x1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

url = "https://www.ssg.com/page/pc/SpecialPrice.ssg"

driver.get(url)

driver.quit()
