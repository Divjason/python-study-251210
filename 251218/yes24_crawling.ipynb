# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.yes24.com/product/category/steadyseller?categoryNumber=001001025"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

books = soup.select("ul#yesBestList > li")

for book in books :
    book_title = book.select_one("div.info_row.info_name a.gd_name").text.strip()
    print(book_title)
# Out:
# 돈의 심리학 (30만 부 기념 스페셜 에디션)
# 돈의 속성 400쇄 리커버
# 불변의 법칙
# 자본주의
# 트렌드 코리아 2025
# 박태웅의 AI 강의 2025
# 부자 아빠 가난한 아빠 20주년 특별 기념판
# 한 번 배워서 평생 써먹는 박곰희 투자법
# 전설로 떠나는 월가의 영웅
# 트럼프 2.0 시대
# 생각에 관한 생각
# 나는 미국 월배당 ETF로 40대에 은퇴한다
# 미국주식 처음공부
# 주식투자 무작정 따라하기
# 린치핀
# 월 50만 원으로 8억 만드는 배당머신
# 부의 추월차선 (10주년 스페셜 에디션)
# 달러는 왜 비트코인을 싫어하는가
# 마법의 연금 굴리기
# 돈, 뜨겁게 사랑하고 차갑게 다루어라
# 가난한 찰리의 연감
# 시대예보: 호명사회
# 혼자 해도 프로 선생님처럼 잘 만드는 학교 수업 자료 with 캔바 Canva
# 부의 인문학 (20만부 기념 개정증보판)
